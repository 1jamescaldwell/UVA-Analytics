# %% [markdown]
# James Caldwell, UVA IRA, Feb 2026 <br>
# This script loads 3 excel files from qlik (enrollment, admissions, and degrees) and calculates the various groupings for the College Graduate Survey. There are ~700 line items calculated.

# %% [markdown]
# To do: fix citizenship unknown, country not listed, country naming check

# %%
import numpy as np
import pandas as pd
from dotenv import load_dotenv
import os

# print(os.getcwd())

template = pd.read_csv('CGS-survey-template-2025.csv',
                       encoding="cp1252",
                       skiprows=1)

# Load environment variables
load_dotenv()
enrollment_file_path = os.getenv('enrollment') 
enrollment = pd.read_excel(enrollment_file_path)
degrees_file_path = os.getenv('degrees') 
degrees = pd.read_excel(degrees_file_path)
admissions_file_path = os.getenv('admissions') 
admissions = pd.read_excel(admissions_file_path)

### Process degrees data, sorting then dropping duplicates on SSID
degree_order = ['DOCT', 'MAST', 'EDS', 'CERT']
# Convert the column to a Categorical with that order
degrees["Degree Level"] = pd.Categorical(degrees["Degree Level"], categories=degree_order, ordered=True)
# Now sort by SSID first, then by the categorical degree
degrees.sort_values(by=['Student System ID', "Degree Level"], inplace=True)
degrees.drop_duplicates(subset=['Student System ID'], keep='first', inplace=True)
enrollment.rename(columns={"Primary Degree Level": "Degree Level"}, inplace=True)

### Process admissions data, sorting then dropping duplicates on SSID
degree_order = ['DOCT', 'MAST', 'EDS', 'CERT']
# Convert the column to a Categorical with that order
admissions["Degree Level"] = pd.Categorical(admissions["Degree Level"], categories=degree_order, ordered=True)
admissions["Enrollment Flag"] = pd.Categorical(admissions["Enrollment Flag"], categories=["Y", "N"], ordered=True)
admissions["OfferFlag"] = pd.Categorical(admissions["OfferFlag"], categories=[1, 0], ordered=True)
admissions.sort_values(
    by=["Student System ID", "Enrollment Flag", "Degree Level", "OfferFlag"],
    ascending=[True, True, True, True],
    inplace=True)
admissions.drop_duplicates(subset=['Student System ID'], keep='first', inplace=True)

# %%
MASTERS_OTHER = ["MAST", "COS", "EDS", "CERT"]
DOCTORAL = ["DOCT"]

GENDER_MAP = {
    "men": ["M"],
    "women": ["F"],
    "other": ["X", "U"],
    "total": ["M", "F", "X", "U"]
}

# %%
def count_from_question(question, df):
    sub = df.copy()
    question = question.strip().lower().replace("–", "-").replace("-", "-")
    # print(question)
    # --- First-time vs Total ---
    if "first-time" in question:
        # print("Filtering for first-time students...")
        sub = sub[sub["New/Returning/Transfer Status"] == "New"]

    # --- Degree level ---
    if "master" in question:
        sub = sub[sub["Degree Level"].isin(MASTERS_OTHER)]
    elif "doct" in question:
        sub = sub[sub["Degree Level"].isin(DOCTORAL)]

    # --- Full-time / Part-time ---
    if "full-time" in question:
        sub = sub[sub["Full or Part Time Status"] == "Full-Time"]
    elif "part-time" in question:
        sub = sub[sub["Full or Part Time Status"] == "Part-Time"]

    # --- Gender ---
    # This logic captures "other" gender, but not "other" from "Master's & other"
    gender_question = question.replace("& other", "")
    for label, codes in GENDER_MAP.items():
        if f" {label}" in gender_question:
            # print(label)
            sub = sub[sub["Gender"].isin(codes)]

    # --- Ethnicity ---
    if "hispanic" in question:
        print('yep: ' + question)
        sub = sub[sub["IPEDS Race"] == "Hispanic"]
    if "american" in question:
        sub = sub[sub["IPEDS Race"] == "American Indian or Alaska Native"]
    if "asian" in question:
        sub = sub[sub["IPEDS Race"] == "Asian"]
    if "black" in question:
        sub = sub[sub["IPEDS Race"] == "Black or African American"]
    if "hawaiian" in question:
        sub = sub[sub["IPEDS Race"] == "Native Hawaiian or Other Pacific Islander"]
    if "white" in question:
        sub = sub[sub["IPEDS Race"] == "White"]
    if "two or more" in question:
        sub = sub[sub["IPEDS Race"] == "Multi-Race"]
    if "international" in question:
        sub = sub[sub["IPEDS Race"] == "Non-Resident Alien"]
    if "unknown" in question:
        sub = sub[sub["IPEDS Race"] == "Race and Ethnicity Unknown"]
    if "citizens and permanent" in question:
        sub = sub[sub["IPEDS Race"] != "Non-Resident Alien"]

    # --- Country-based questions ---
    parts = [p.strip() for p in question.split(",")]
    if len(parts) > 2: # 3 part questions are country-based
        possible_country = parts[1] #countries are always the second part of the question
        country_series = df["Foreign Citizen Country Desc"].str.strip().str.lower()
        possible_country_norm = possible_country.strip().lower()

        if possible_country_norm in country_series.unique():
            sub = sub.loc[country_series == possible_country_norm]
        else:
            print('skipped: ' + question)
            return '-'
    # --- Admissions ---
    if 'offers' in question:
        sub = sub[sub["OfferFlag"] == 1]
    if 'not accepted' in question:
        sub = sub[sub["OfferFlag"] == 0]

    if df.equals(sub):
        print('skipped: ' + question)
        return '-'
    if sub.empty:
        return 0

    return sub["Student System ID"].nunique()

results = {} 
# ensure row 3 exists
template.loc[3] = -1

for col, question in template.iloc[2, :].items():
    if isinstance(question, str) and "Enrollment" in question:
        template.loc[3, col] = count_from_question(question, enrollment)
        # results[question] = count_from_question(question, enrollment)
    elif isinstance(question, str) and ("Degree" in question or "Certificates" in question):
        template.loc[3, col] = count_from_question(question, degrees)
        # results[question] = count_from_question(question, degrees)
    elif isinstance(question, str) and ("Admission" in question or "Applications" in question):
        template.loc[3, col] = count_from_question(question, admissions)
        # results[question] = count_from_question(question, degrees)
    else: # these should be enrollment section IV and V
        template.loc[3, col] = count_from_question(question, enrollment)
        # results[question] = count_from_question(question, enrollment)    

template_long = template.T
# Out:
# skipped: label
# skipped: institution code
# skipped: ipeds id code
# skipped: cip code (enter 00 for total)
# skipped: survey year
# skipped: graduate certificates, total
# skipped: total applications, total
# yep: master’s & other first-time, hispanic/latino (of any race) men
# yep: master’s & other first-time, hispanic/latino (of any race) women
# yep: master’s & other first-time, hispanic/latino (of any race) other
# yep: master’s & other first-time, hispanic/latino (of any race) total
# yep: master’s & other total, hispanic/latino (of any race) men
# yep: master’s & other total, hispanic/latino (of any race) women
# yep: master’s & other total, hispanic/latino (of any race) other
# yep: master’s & other total, hispanic/latino (of any race) total
# yep: doctoral first-time, hispanic/latino (of any race) men
# yep: doctoral first-time, hispanic/latino (of any race) women
# yep: doctoral first-time, hispanic/latino (of any race) other
# yep: doctoral first-time, hispanic/latino (of any race) total
# yep: doctoral total, hispanic/latino (of any race) men
# yep: doctoral total, hispanic/latino (of any race) women
# yep: doctoral total, hispanic/latino (of any race) other
# yep: doctoral total, hispanic/latino (of any race) total
# yep: master’s & other applications, hispanic/latino (of any race) men
# yep: master’s & other applications, hispanic/latino (of any race) women
# yep: master’s & other applications, hispanic/latino (of any race) other
# yep: master’s & other applications, hispanic/latino (of any race) total
# yep: master’s & other offers of admission, hispanic/latino (of any race) men
# yep: master’s & other offers of admission, hispanic/latino (of any race) women
# yep: master’s & other offers of admission, hispanic/latino (of any race) other
# yep: master’s & other offers of admission, hispanic/latino (of any race) total
# yep: doctoral applications, hispanic/latino (of any race) men
# yep: doctoral applications, hispanic/latino (of any race) women
# yep: doctoral applications, hispanic/latino (of any race) other
# yep: doctoral applications, hispanic/latino (of any race) total
# yep: doctoral offers of admission, hispanic/latino (of any race) men
# yep: doctoral offers of admission, hispanic/latino (of any race) women
# yep: doctoral offers of admission, hispanic/latino (of any race) other
# yep: doctoral offers of admission, hispanic/latino (of any race) total
# skipped: rural status, total applications
# skipped: disability status, total applications
# skipped: veteran status, total applications
# skipped: first-generation status, total applications
# skipped: total applications, iran, master’s and other
# skipped: total applications, iran, doctorate
# skipped: total applications, iran, total
# skipped: total applications, south korea, master’s and other
# skipped: total applications, south korea, doctorate
# skipped: total applications, south korea, total
# skipped: total applications, taiwan, master’s and other
# skipped: total applications, taiwan, doctorate
# skipped: total applications, taiwan, total
# skipped: total applications, turkey/türkiye, master’s and other
# skipped: total applications, turkey/türkiye, doctorate
# skipped: total applications, turkey/türkiye, total
# skipped: total applications, vietnam, master’s and other
# skipped: total applications, vietnam, doctorate
# skipped: total applications, vietnam, total
# skipped: total applications, other countries not listed, master’s and other
# skipped: total applications, other countries not listed, doctorate
# skipped: total applications, other countries not listed, total
# skipped: total applications, total international students, master’s and other
# skipped: total applications, total international students, doctorate
# skipped: total applications, total international students, total
# skipped: offers of admissions, iran, master’s and other
# skipped: offers of admissions, iran, doctorate
# skipped: offers of admissions, iran, total
# skipped: offers of admissions, south korea, master’s and other
# skipped: offers of admissions, south korea, doctorate
# skipped: offers of admissions, south korea, total
# skipped: offers of admissions, taiwan, master’s and other
# skipped: offers of admissions, taiwan, doctorate
# skipped: offers of admissions, taiwan, total
# skipped: offers of admissions, turkey/türkiye, master’s and other
# skipped: offers of admissions, turkey/türkiye, doctorate
# skipped: offers of admissions, turkey/türkiye, total
# skipped: offers of admissions, vietnam, master’s and other
# skipped: offers of admissions, vietnam, doctorate
# skipped: offers of admissions, vietnam, total
# skipped: offers of admissions, other countries not listed, master’s and other
# skipped: offers of admissions, other countries not listed, doctorate
# skipped: offers of admissions, other countries not listed, total
# skipped: offers of admissions, total international students, master’s and other
# skipped: offers of admissions, total international students, doctorate
# skipped: offers of admissions, total international students, total
# skipped: first-time enrollment, iran, master’s and other
# skipped: first-time enrollment, iran, doctorate
# skipped: first-time enrollment, iran, total
# skipped: first-time enrollment, south korea, master’s and other
# skipped: first-time enrollment, south korea, doctorate
# skipped: first-time enrollment, south korea, total
# skipped: first-time enrollment, taiwan, master’s and other
# skipped: first-time enrollment, taiwan, doctorate
# skipped: first-time enrollment, taiwan, total
# skipped: first-time enrollment, turkey/türkiye, master’s and other
# skipped: first-time enrollment, turkey/türkiye, doctorate
# skipped: first-time enrollment, turkey/türkiye, total
# skipped: first-time enrollment, vietnam, master’s and other
# skipped: first-time enrollment, vietnam, doctorate
# skipped: first-time enrollment, vietnam, total
# skipped: first-time enrollment, other countries not listed, master’s and other
# skipped: first-time enrollment, other countries not listed, doctorate
# skipped: first-time enrollment, other countries not listed, total
# skipped: first-time enrollment, total international students, master’s and other
# skipped: first-time enrollment, total international students, doctorate
# skipped: first-time enrollment, total international students, total
# skipped: total enrollment, iran, master’s and other
# skipped: total enrollment, iran, doctorate
# skipped: total enrollment, iran, total
# skipped: total enrollment, south korea, master’s and other
# skipped: total enrollment, south korea, doctorate
# skipped: total enrollment, south korea, total
# skipped: total enrollment, taiwan, master’s and other
# skipped: total enrollment, taiwan, doctorate
# skipped: total enrollment, taiwan, total
# skipped: total enrollment, turkey/türkiye, master’s and other
# skipped: total enrollment, turkey/türkiye, doctorate
# skipped: total enrollment, turkey/türkiye, total
# skipped: total enrollment, vietnam, master’s and other
# skipped: total enrollment, vietnam, doctorate
# skipped: total enrollment, vietnam, total
# skipped: total enrollment, other countries not listed, master’s and other
# skipped: total enrollment, other countries not listed, doctorate
# skipped: total enrollment, other countries not listed, total
# skipped: total enrollment, total international students, master’s and other
# skipped: total enrollment, total international students, doctorate
# skipped: total enrollment, total international students, total

# %%
admissions.columns
# Out:
# Index(['Student System ID', 'Degree Level', 'Gender', 'IPEDS Race',
#        'Foreign Citizen Country Desc', 'US Citizenship Status',
#        'Enrollment Flag', 'OfferFlag'],
#       dtype='object')

# %%
template.shape
# Out:
# (4, 794)

# %%
len(results)
# Out:
# 794

# %%
template.iloc[3,:].value_counts()
# Out:
# -1     580
# -       46
# 2        8
# 6        8
# 7        7
#       ...
# 108      1
# 180      1
# 69       1
# 89       1
# 48       1
# Name: 3, Length: 73, dtype: int64

# %% [markdown]
# James Caldwell <br>
# UVA IRA, 10/8/2025 <br>
#
# This Python script automates the extraction of error tables from the SCHEV Institutional Portal and merges them with a VCSIN-to-SSID mapping file. The final result is exported to an Excel workbook with each error code on a separate sheet.

# %% [markdown]
# Features: <br>
# Opens the SCHEV portal in a Chrome browser via Selenium.
#
# Allows manual login for secure access.
#
# Extracts links corresponding to error codes.
#
# Follows each link to retrieve error tables.
#
# Merges error tables with a local VCSIN-to-SSID Excel mapping.
#
# Saves all merged tables to a single Excel workbook with meaningful sheet names.

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin
from io import StringIO
import re

# Variables to change
url = "https://portals.schev.edu/institutions/PUBLIC/UVA/Viewerrorsummary.asp?tablename=fa&repyear=2425"
VCSIN_to_SSID_path = r"path here"
chrome_driver_path = r"path here"
excel_output_path = r"path here"

# Set up Selenium WebDriver
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)#, options=options)

# Open the login page
driver.get(url)

print("Browser opened. Please log in manually.")
input("Press ENTER here *after* you have logged in successfully...")

# After you log in, grab the page
driver.get(url)
html = driver.page_source
mysoup = BeautifulSoup(html, 'html.parser')

# Load VCSIN to SSID mapping file
print("Loading VCSIN to SSID mapping file...")
VCSIN_to_SSID = pd.read_excel(VCSIN_to_SSID_path)

# === Extract all links ===
links = []
for a in mysoup.find_all('a', href=True):
    href = a['href']
    # Skip empty, anchor, or javascript links
    if href.startswith('#') or href.lower().startswith('javascript'):
        continue
    # Convert relative URLs to absolute
    full_link = href if href.startswith('http') else driver.current_url.rsplit('/', 1)[0] + '/' + href
    if 'viewError' in full_link:  # filter for relevant links
        links.append(full_link)

print(f"\nFound {len(links)} error code links:")
# for l in links[:10]:  # preview first 10
#     print(l)

all_error_tables_for_excel = []
all_error_table_names_for_excel = []
# # === Visit each link ===
for i, link in enumerate(links, start=1): # links[:3]
    print(f"\nVisiting link {i}/{len(links)}: {link}")
    try:
        driver.get(link)
        time.sleep(1)  # wait for page to load; adjust as needed
        
        page_html = driver.page_source
        page_soup = BeautifulSoup(page_html, 'html.parser')

        # Find the <script> tag containing the specific substring for error table url
        link_tag = page_soup.find(src=lambda value: value and "ErrorsList.asp" in value)
        if link_tag:
            
            ## save Error Name for excel sheet name
            match = re.search(r'Errcode=([^&"]+)', page_html)
            if match:
                error_code = match.group(1)
                print(f'Error Code: {error_code}')
                all_error_table_names_for_excel.append(error_code)  # error_code = match.group(1)

            ## Follow error table URL and save
            relative_url = link_tag['src']
            # print("Relative URL:", relative_url)

            # Convert to absolute
            base = "https://portals.schev.edu/institutions/PUBLIC/UVA/"
            table_url = urljoin(base, relative_url)
            # print("Full URL:", table_url)

            driver.get(table_url)
            time.sleep(1) # wait for page to load; adjust as needed
            table_page_html = driver.page_source

            # Parse tables with pandas
            tables = pd.read_html(StringIO(table_page_html), header=0)
            df = tables[0]  # Get the first table, adjust index if needed

            # Merge with VCSIN_to_SSID to get SSID
            if 'SOCSEC1' in df.columns:
                df = df.merge(VCSIN_to_SSID, how='left', left_on='SOCSEC1', right_on='VCSIN').drop(columns='VCSIN')

            all_error_tables_for_excel.append(df)

        else:
            print("No match found.")
    except Exception as e:
        print(f"Error visiting {link}: {e}")

print("\nDone visiting all links.")

print("\nSaving to Excel...")
with pd.ExcelWriter(excel_output_path, engine='openpyxl') as writer:
    for i, df in enumerate(all_error_tables_for_excel):
        df.to_excel(writer, sheet_name=all_error_table_names_for_excel[i], index=False)

driver.quit()
# Out:
# Browser opened. Please log in manually.
# Loading VCSIN to SSID mapping file...
#
# Found 84 error code links:
#
# Visiting link 1/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AEF001W02&ErrType=W&TableName=fa&Repyear=2425&Position=340
# Error Code: AEF001W02
#
# Visiting link 2/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AEF003W02&ErrType=W&TableName=fa&Repyear=2425&Position=354
# Error Code: AEF003W02
#
# Visiting link 3/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFA004W01&ErrType=W&TableName=fa&Repyear=2425&Position=68
# Error Code: AFA004W01
#
# Visiting link 4/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFA008W01&ErrType=W&TableName=fa&Repyear=2425&Position=74
# Error Code: AFA008W01
#
# Visiting link 5/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE001E02&ErrType=E&TableName=fa&Repyear=2425&Position=123
# Error Code: AFE001E02
#
# Visiting link 6/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE001W04&ErrType=W&TableName=fa&Repyear=2425&Position=123
# Error Code: AFE001W04
#
# Visiting link 7/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE002E02&ErrType=E&TableName=fa&Repyear=2425&Position=130
# Error Code: AFE002E02
#
# Visiting link 8/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE004E02&ErrType=E&TableName=fa&Repyear=2425&Position=144
# Error Code: AFE004E02
#
# Visiting link 9/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE005W02&ErrType=W&TableName=fa&Repyear=2425&Position=151
# Error Code: AFE005W02
#
# Visiting link 10/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE009W02&ErrType=W&TableName=fa&Repyear=2425&Position=193
# Error Code: AFE009W02
#
# Visiting link 11/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE010E02&ErrType=E&TableName=fa&Repyear=2425&Position=179
# Error Code: AFE010E02
#
# Visiting link 12/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AFE015E02&ErrType=E&TableName=fa&Repyear=2425&Position=466
# Error Code: AFE015E02
#
# Visiting link 13/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AIN002W02&ErrType=W&TableName=fa&Repyear=2425&Position=291
# Error Code: AIN002W02
#
# Visiting link 14/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AIN004W02&ErrType=W&TableName=fa&Repyear=2425&Position=305
# Error Code: AIN004W02
#
# Visiting link 15/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AIN007W02&ErrType=W&TableName=fa&Repyear=2425&Position=319
# Error Code: AIN007W02
#
# Visiting link 16/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=ANI001W02&ErrType=W&TableName=fa&Repyear=2425&Position=284
# Error Code: ANI001W02
#
# Visiting link 17/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AOT003W02&ErrType=W&TableName=fa&Repyear=2425&Position=403
# Error Code: AOT003W02
#
# Visiting link 18/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AOT005W02&ErrType=W&TableName=fa&Repyear=2425&Position=417
# Error Code: AOT005W02
#
# Visiting link 19/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=AOT007W02&ErrType=W&TableName=fa&Repyear=2425&Position=431
# Error Code: AOT007W02
#
# Visiting link 20/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=ASI005W01&ErrType=W&TableName=fa&Repyear=2425&Position=47
# Error Code: ASI005W01
#
# Visiting link 21/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=ASI006W02&ErrType=W&TableName=fa&Repyear=2425&Position=56
# Error Code: ASI006W02
#
# Visiting link 22/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BEF003E99&ErrType=E&TableName=fa&Repyear=2425&Position=354
# Error Code: BEF003E99
#
# Visiting link 23/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA003E03&ErrType=E&TableName=fa&Repyear=2425&Position=67
# Error Code: BFA003E03
#
# Visiting link 24/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA003E04&ErrType=E&TableName=fa&Repyear=2425&Position=67
# Error Code: BFA003E04
#
# Visiting link 25/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA005E01&ErrType=E&TableName=fa&Repyear=2425&Position=70
# Error Code: BFA005E01
#
# Visiting link 26/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA005E02&ErrType=E&TableName=fa&Repyear=2425&Position=70
# Error Code: BFA005E02
#
# Visiting link 27/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA005E03&ErrType=E&TableName=fa&Repyear=2425&Position=70
# Error Code: BFA005E03
#
# Visiting link 28/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA005E04&ErrType=E&TableName=fa&Repyear=2425&Position=70
# Error Code: BFA005E04
#
# Visiting link 29/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA009E02&ErrType=E&TableName=fa&Repyear=2425&Position=76
# Error Code: BFA009E02
#
# Visiting link 30/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA009E03&ErrType=E&TableName=fa&Repyear=2425&Position=76
# Error Code: BFA009E03
#
# Visiting link 31/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFA010E03&ErrType=E&TableName=fa&Repyear=2425&Position=77
# Error Code: BFA010E03
#
# Visiting link 32/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE001E03&ErrType=E&TableName=fa&Repyear=2425&Position=123
# Error Code: BFE001E03
#
# Visiting link 33/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE001W04&ErrType=W&TableName=fa&Repyear=2425&Position=123
# Error Code: BFE001W04
#
# Visiting link 34/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE002E03&ErrType=E&TableName=fa&Repyear=2425&Position=130
# Error Code: BFE002E03
#
# Visiting link 35/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE002W04&ErrType=W&TableName=fa&Repyear=2425&Position=130
# Error Code: BFE002W04
#
# Visiting link 36/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE004W03&ErrType=W&TableName=fa&Repyear=2425&Position=144
# Error Code: BFE004W03
#
# Visiting link 37/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE004W04&ErrType=W&TableName=fa&Repyear=2425&Position=144
# Error Code: BFE004W04
#
# Visiting link 38/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE005W06&ErrType=W&TableName=fa&Repyear=2425&Position=151
# Error Code: BFE005W06
#
# Visiting link 39/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE008E03&ErrType=E&TableName=fa&Repyear=2425&Position=172
# Error Code: BFE008E03
#
# Visiting link 40/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE010W03&ErrType=W&TableName=fa&Repyear=2425&Position=179
# Error Code: BFE010W03
#
# Visiting link 41/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE010W04&ErrType=W&TableName=fa&Repyear=2425&Position=179
# Error Code: BFE010W04
#
# Visiting link 42/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE010W06&ErrType=W&TableName=fa&Repyear=2425&Position=179
# Error Code: BFE010W06
#
# Visiting link 43/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BFE015E03&ErrType=E&TableName=fa&Repyear=2425&Position=466
# Error Code: BFE015E03
#
# Visiting link 44/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BIN004E99&ErrType=E&TableName=fa&Repyear=2425&Position=305
# Error Code: BIN004E99
#
# Visiting link 45/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BNB001W03&ErrType=W&TableName=fa&Repyear=2425&Position=86
# Error Code: BNB001W03
#
# Visiting link 46/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BNB006W01&ErrType=W&TableName=fa&Repyear=2425&Position=93
# Error Code: BNB006W01
#
# Visiting link 47/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BNB006W02&ErrType=W&TableName=fa&Repyear=2425&Position=93
# Error Code: BNB006W02
#
# Visiting link 48/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BNB006W03&ErrType=W&TableName=fa&Repyear=2425&Position=93
# Error Code: BNB006W03
#
# Visiting link 49/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BNB006W05&ErrType=W&TableName=fa&Repyear=2425&Position=93
# Error Code: BNB006W05
#
# Visiting link 50/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BOT003E99&ErrType=E&TableName=fa&Repyear=2425&Position=403
# Error Code: BOT003E99
#
# Visiting link 51/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BSI003W01&ErrType=W&TableName=fa&Repyear=2425&Position=40
# Error Code: BSI003W01
#
# Visiting link 52/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BSI006W01&ErrType=W&TableName=fa&Repyear=2425&Position=56
# Error Code: BSI006W01
#
# Visiting link 53/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BSI007E01&ErrType=E&TableName=fa&Repyear=2425&Position=58
# Error Code: BSI007E01
#
# Visiting link 54/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST004E03&ErrType=E&TableName=fa&Repyear=2425&Position=221
# Error Code: BST004E03
#
# Visiting link 55/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST004E09&ErrType=E&TableName=fa&Repyear=2425&Position=221
# Error Code: BST004E09
#
# Visiting link 56/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST005E01&ErrType=E&TableName=fa&Repyear=2425&Position=228
# Error Code: BST005E01
#
# Visiting link 57/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST005W06&ErrType=W&TableName=fa&Repyear=2425&Position=228
# Error Code: BST005W06
#
# Visiting link 58/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST005W09&ErrType=W&TableName=fa&Repyear=2425&Position=228
# Error Code: BST005W09
#
# Visiting link 59/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST009E09&ErrType=E&TableName=fa&Repyear=2425&Position=256
# Error Code: BST009E09
#
# Visiting link 60/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST012E09&ErrType=E&TableName=fa&Repyear=2425&Position=270
# Error Code: BST012E09
#
# Visiting link 61/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST013E03&ErrType=E&TableName=fa&Repyear=2425&Position=480
# Error Code: BST013E03
#
# Visiting link 62/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST013E09&ErrType=E&TableName=fa&Repyear=2425&Position=480
# Error Code: BST013E09
#
# Visiting link 63/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST013W04&ErrType=W&TableName=fa&Repyear=2425&Position=480
# Error Code: BST013W04
#
# Visiting link 64/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST014E03&ErrType=E&TableName=fa&Repyear=2425&Position=487
# Error Code: BST014E03
#
# Visiting link 65/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST014E09&ErrType=E&TableName=fa&Repyear=2425&Position=487
# Error Code: BST014E09
#
# Visiting link 66/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=BST014W04&ErrType=W&TableName=fa&Repyear=2425&Position=487
# Error Code: BST014W04
#
# Visiting link 67/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=CSI006W01&ErrType=WII&TableName=fa&Repyear=2425&Position=56
# Error Code: CSI006W01
#
# Visiting link 68/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DFE001W02&ErrType=WAFA&TableName=fa&Repyear=2425&Position=123
# Error Code: DFE001W02
#
# Visiting link 69/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DFE002E02&ErrType=EAFA&TableName=fa&Repyear=2425&Position=130
# Error Code: DFE002E02
#
# Visiting link 70/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DFE004E02&ErrType=EAFA&TableName=fa&Repyear=2425&Position=144
# Error Code: DFE004E02
#
# Visiting link 71/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DFE010E02&ErrType=EAFA&TableName=fa&Repyear=2425&Position=179
# Error Code: DFE010E02
#
# Visiting link 72/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DKI004E01&ErrType=E&TableName=fa&Repyear=2425&Position=10
# Error Code: DKI004E01
#
# Visiting link 73/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DKI009E01&ErrType=E&TableName=fa&Repyear=2425&Position=34
# Error Code: DKI009E01
#
# Visiting link 74/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DKI009E02&ErrType=E&TableName=fa&Repyear=2425&Position=34
# Error Code: DKI009E02
#
# Visiting link 75/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DKI009W03&ErrType=W&TableName=fa&Repyear=2425&Position=34
# Error Code: DKI009W03
#
# Visiting link 76/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DKI009W04&ErrType=W&TableName=fa&Repyear=2425&Position=34
# Error Code: DKI009W04
#
# Visiting link 77/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DNB008W01&ErrType=WPC&TableName=fa&Repyear=2425&Position=105
# Error Code: DNB008W01
#
# Visiting link 78/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DST005W02&ErrType=WAFA&TableName=fa&Repyear=2425&Position=228
# Error Code: DST005W02
#
# Visiting link 79/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DST012E01&ErrType=E&TableName=fa&Repyear=2425&Position=270
# Error Code: DST012E01
#
# Visiting link 80/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DST012E02&ErrType=E&TableName=fa&Repyear=2425&Position=270
# Error Code: DST012E02
#
# Visiting link 81/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DST013E01&ErrType=E&TableName=fa&Repyear=2425&Position=480
# Error Code: DST013E01
#
# Visiting link 82/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=DST014E01&ErrType=E&TableName=fa&Repyear=2425&Position=487
# Error Code: DST014E01
#
# Visiting link 83/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=ZKI004E08&ErrType=E&TableName=fa&Repyear=2425&Position=59
# Error Code: ZKI004E08
#
# Visiting link 84/84: https://portals.schev.edu/institutions/PUBLIC/UVA/viewErrors.asp?Err=ZST014W16&ErrType=W&TableName=fa&Repyear=2425&Position=487
# Error Code: ZST014W16
#
# Done visiting all links.
#
# Saving to Excel...
